# %% [markdown]
# <a href="https://colab.research.google.com/github/UniVR-DH/DBMS-course/blob/main/notebooks/lab03-duckdb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SQL exercise with DuckDB in Jupyter Notebooks
# In this notebook we use DuckDB as a DBMS, plus we use some plugins to simplify your way to run SQL queries.

# %% [markdown]
# ## Library Import and Configuration

# %%
# !pip install --quiet duckdb
# !pip install --quiet jupysql
# !pip install --quiet duckdb-engine
# !pip install --quiet pandas

# %%
import duckdb
import pandas as pd
# Import jupysql Jupyter extension to create SQL cells
# this avoids the need to run SQL in python
# %load_ext sql

# %% [markdown]
# **We configure jupysql to return data as a Pandas dataframe and have less verbose output**

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %% [markdown]
# ## Initialize the Database

# %%
# Run DuckDB in main memory, remember to export to file
# %sql duckdb:///:memory:
# If we want to save the DB to file we can use the following,
# but then we need to remember to download the file
# %sql duckdb:///myfile.db

# %% [markdown]
# An entire Jupyter cell can be used as a SQL cell by placing `%%sql` at the start of the cell. Query results will be displayed as a Pandas DF.

# %%
# %%sql
# SELECT 1=2 as test, 'Hello people' as message, 3*12345 as math  ;
# Out:
#     test       message   math
# 0  False  Hello people  37035

# %% [markdown]
# **We can use any CSV file**, we can add it to jupyter or download it from the web

# %%
# !wget  -O irpef.regione.2024.csv https://www1.finanze.gov.it/finanze/analisi_stat/public/v_4_0_0/contenuti/REG_calcolo_irpef_2024.csv?d=1615465800
# !wget  -O irpef.sesso.2024.csv https://www1.finanze.gov.it/finanze/analisi_stat/public/v_4_0_0/contenuti/sesso_calcolo_irpef_2024.csv?d=1615465800
# Out:
# --2025-11-20 12:39:33--  https://www1.finanze.gov.it/finanze/analisi_stat/public/v_4_0_0/contenuti/REG_calcolo_irpef_2024.csv?d=1615465800
# Resolving www1.finanze.gov.it (www1.finanze.gov.it)... 217.175.52.178
# Connecting to www1.finanze.gov.it (www1.finanze.gov.it)|217.175.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 194624 (190K) [text/csv]
# Saving to: ‘irpef.regione.2024.csv’
#
# irpef.regione.2024. 100%[===================>] 190.06K   370KB/s    in 0.5s
#
# 2025-11-20 12:39:34 (370 KB/s) - ‘irpef.regione.2024.csv’ saved [194624/194624]
#
# --2025-11-20 12:39:34--  https://www1.finanze.gov.it/finanze/analisi_stat/public/v_4_0_0/contenuti/sesso_calcolo_irpef_2024.csv?d=1615465800
# Resolving www1.finanze.gov.it (www1.finanze.gov.it)... 217.175.52.178
# Connecting to www1.finanze.gov.it (www1.finanze.gov.it)|217.175.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22044 (22K) [text/csv]
# Saving to: ‘irpef.sesso.2024.csv’
#
# irpef.sesso.2024.cs 100%[===================>]  21.53K  --.-KB/s    in 0.1s
#
# 2025-11-20 12:39:35 (168 KB/s) - ‘irpef.sesso.2024.csv’ saved [22044/22044]

# %%
# %%sql
# SELECT *
# FROM read_csv('irpef.regione.2024.csv', header=true, auto_detect=true)
# LIMIT 10;
# Out:
#   Classi di reddito complessivo in euro   Regione Numero contribuenti  \
# 0                      minore di -1.000  Piemonte                 152
# 1                         da -1.000 a 0  Piemonte                  53
# 2                                  zero  Piemonte              85.410
# 3                          da 0 a 1.000  Piemonte             141.686
# 4                      da 1.000 a 1.500  Piemonte              34.992
# 5                      da 1.500 a 2.000  Piemonte              29.656
# 6                      da 2.000 a 2.500  Piemonte              26.388
# 7                      da 2.500 a 3.000  Piemonte              24.353
# 8                      da 3.000 a 3.500  Piemonte              22.801
# 9                      da 3.500 a 4.000  Piemonte              22.045
#
#   Reddito complessivo - Frequenza Reddito complessivo - Ammontare in euro  \
# 0                             152                              -2.565.663
# 1                              53                                 -22.715
# 2                               0                                       0
# 3                         141.686                              60.396.511
# 4                          34.992                              43.455.671
# 5                          29.656                              51.894.397
# 6                          26.388                              59.397.838
# 7                          24.353                              67.017.265
# 8                          22.801                              74.124.075
# 9                          22.045                              82.709.166
#
#   Reddito complessivo al netto della cedolare secca - Frequenza  \
# 0                                                152
# 1                                                 53
# 2                                                  0
# 3                                            141.053
# 4                                             34.539
# 5                                             29.146
# 6                                             25.678
# 7                                             23.729
# 8                                             22.390
# 9                                             21.404
#
#   Reddito complessivo al netto della cedolare secca - Ammontare in euro  \
# 0                                         -2.625.873
# 1                                            -22.715
# 2                                                  0
# 3                                         59.633.501
# 4                                         42.106.068
# 5                                         49.440.257
# 6                                         55.557.875
# 7                                         62.444.522
# 8                                         69.952.704
# 9                                         77.079.073
#
#    Deduzione per abitazione principale - Frequenza  \
# 0                                           69.000
# 1                                           20.000
# 2                                            0.000
# 3                                           54.997
# 4                                            8.605
# 5                                            5.633
# 6                                            4.859
# 7                                            4.496
# 8                                            4.168
# 9                                            4.106
#
#   Deduzione per abitazione principale - Ammontare in euro  \
# 0                                             47.662
# 1                                             11.090
# 2                                                  0
# 3                                         21.474.821
# 4                                          6.296.115
# 5                                          3.805.535
# 6                                          2.754.442
# 7                                          2.260.772
# 8                                          2.080.273
# 9                                          1.916.134
#
#    Oneri deducibili - Frequenza  ... Differenza - Frequenza  \
# 0                        75.000  ...                     76
# 1                        27.000  ...                     10
# 2                         6.591  ...                  1.294
# 3                         9.824  ...                 16.530
# 4                         2.505  ...                  7.368
# 5                         1.977  ...                  6.657
# 6                         1.821  ...                  6.394
# 7                         1.714  ...                  6.144
# 8                         1.813  ...                  6.245
# 9                         1.928  ...                  6.489
#
#   Differenza - Ammontare in euro  \
# 0                       -329.201
# 1                        -10.968
# 2                     -1.358.567
# 3                     -1.916.819
# 4                       -634.617
# 5                       -876.305
# 6                       -939.782
# 7                     -1.170.343
# 8                     -1.479.297
# 9                     -1.667.360
#
#   Eccedenza d'imposta risultante dalla precedente dichiarazione - Frequenza  \
# 0                                             70.000
# 1                                             23.000
# 2                                              5.675
# 3                                              6.814
# 4                                              1.595
# 5                                              1.212
# 6                                              1.222
# 7                                              1.076
# 8                                              1.092
# 9                                              1.074
#
#   Eccedenza d'imposta risultante dalla precedente dichiarazione - Ammontare in euro  \
# 0                                            666.133
# 1                                             77.873
# 2                                          5.337.157
# 3                                          6.609.629
# 4                                          1.705.394
# 5                                          1.210.843
# 6                                          1.238.735
# 7                                            909.266
# 8                                          1.000.044
# 9                                          1.081.212
#
#   Acconti versati - Frequenza Acconti versati - Ammontare in euro  \
# 0                         NaN                                None
# 1                         NaN                                None
# 2                       1.200                           1.992.348
# 3                       3.321                           3.045.579
# 4                       1.384                             698.141
# 5                       1.141                             668.142
# 6                       1.169                             728.478
# 7                       1.049                             762.668
# 8                       1.014                             688.844
# 9                     970.000                             692.550
#
#   Irpef a credito - Frequenza Irpef a credito - Ammontare in euro  \
# 0                     112.000                           1.021.709
# 1                      28.000                              89.321
# 2                       7.590                           8.714.771
# 3                      15.349                          11.817.548
# 4                       5.388                           3.151.579
# 5                       5.135                           2.807.682
# 6                       5.161                           2.920.728
# 7                       5.031                           2.774.464
# 8                       5.297                           3.073.033
# 9                       5.397                           3.342.558
#
#   Irpef a debito - Frequenza Irpef a debito - Ammontare in euro
# 0                      0.000                                  0
# 1                      0.000                                  0
# 2                     59.000                             29.348
# 3                      6.699                            327.446
# 4                      2.669                            252.451
# 5                      2.028                            260.045
# 6                      1.796                            281.736
# 7                      1.632                            296.634
# 8                      1.512                            311.430
# 9                      1.608                            400.866
#
# [10 rows x 31 columns]

# %%
# %%sql
# SELECT *
# FROM read_csv('irpef.sesso.2024.csv', header=true, auto_detect=true)
# LIMIT 10;
# Out:
#   Classi di reddito complessivo in euro   Sesso Numero contribuenti  \
# 0                      minore di -1.000  Maschi               1.542
# 1                         da -1.000 a 0  Maschi                 620
# 2                                  zero  Maschi             670.362
# 3                          da 0 a 1.000  Maschi             985.306
# 4                      da 1.000 a 1.500  Maschi             247.408
# 5                      da 1.500 a 2.000  Maschi             203.540
# 6                      da 2.000 a 2.500  Maschi             177.689
# 7                      da 2.500 a 3.000  Maschi             164.554
# 8                      da 3.000 a 3.500  Maschi             151.461
# 9                      da 3.500 a 4.000  Maschi             146.523
#
#   Reddito complessivo - Frequenza Reddito complessivo - Ammontare in euro  \
# 0                           1.542                             -17.102.700
# 1                             620                                -263.406
# 2                               0                                       0
# 3                         985.306                             426.389.300
# 4                         247.408                             307.421.998
# 5                         203.540                             356.339.225
# 6                         177.689                             400.180.779
# 7                         164.554                             453.110.419
# 8                         151.461                             492.558.279
# 9                         146.523                             549.653.236
#
#   Reddito complessivo al netto della cedolare secca - Frequenza  \
# 0                                              1.542
# 1                                                620
# 2                                                  0
# 3                                            981.773
# 4                                            244.940
# 5                                            200.936
# 6                                            174.587
# 7                                            161.157
# 8                                            149.386
# 9                                            143.079
#
#   Reddito complessivo al netto della cedolare secca - Ammontare in euro  \
# 0                                        -17.580.273
# 1                                           -304.120
# 2                                                  0
# 3                                        422.724.226
# 4                                        301.135.929
# 5                                        346.592.293
# 6                                        385.941.091
# 7                                        434.547.619
# 8                                        474.556.252
# 9                                        523.599.921
#
#   Deduzione per abitazione principale - Frequenza  \
# 0                                             633
# 1                                             203
# 2                                            None
# 3                                         324.404
# 4                                          50.466
# 5                                          30.026
# 6                                          23.595
# 7                                          21.880
# 8                                          20.857
# 9                                          20.194
#
#   Deduzione per abitazione principale - Ammontare in euro  \
# 0                                            490.148
# 1                                            119.149
# 2                                               None
# 3                                        127.973.613
# 4                                         37.818.719
# 5                                         20.503.816
# 6                                         13.676.228
# 7                                         11.455.524
# 8                                         10.105.001
# 9                                          9.508.470
#
#    Oneri deducibili - Frequenza  ... Differenza - Frequenza  \
# 0                       757.000  ...                    857
# 1                       227.000  ...                    199
# 2                        54.580  ...                 11.219
# 3                        73.263  ...                 95.871
# 4                        18.136  ...                 43.355
# 5                        13.899  ...                 40.351
# 6                        12.526  ...                 39.721
# 7                        12.037  ...                 40.398
# 8                        11.985  ...                 41.951
# 9                        12.066  ...                 43.489
#
#   Differenza - Ammontare in euro  \
# 0                     -4.327.869
# 1                       -380.691
# 2                    -11.847.552
# 3                    -16.278.952
# 4                     -4.756.572
# 5                     -6.307.929
# 6                     -8.040.480
# 7                     -9.609.673
# 8                    -11.195.955
# 9                    -12.834.961
#
#   Eccedenza d'imposta risultante dalla precedente dichiarazione - Frequenza  \
# 0                                            781.000
# 1                                            285.000
# 2                                             46.769
# 3                                             51.312
# 4                                             11.643
# 5                                              8.878
# 6                                              8.024
# 7                                              7.602
# 8                                              7.176
# 9                                              7.402
#
#   Eccedenza d'imposta risultante dalla precedente dichiarazione - Ammontare in euro  \
# 0                                          5.346.184
# 1                                          1.087.917
# 2                                         53.444.288
# 3                                         58.610.090
# 4                                         13.201.800
# 5                                         10.066.952
# 6                                          9.191.017
# 7                                          8.221.015
# 8                                          7.928.412
# 9                                          7.989.632
#
#   Acconti versati - Frequenza Acconti versati - Ammontare in euro  \
# 0                     132.000                             733.188
# 1                      35.000                              91.166
# 2                       9.993                          17.454.036
# 3                      20.758                          24.179.017
# 4                       8.414                           5.670.715
# 5                       6.653                           4.506.608
# 6                       5.722                           3.963.986
# 7                       5.816                           4.359.743
# 8                       5.748                           4.375.089
# 9                       5.788                           4.490.835
#
#   Irpef a credito - Frequenza Irpef a credito - Ammontare in euro  \
# 0                       1.182                          10.422.880
# 1                         387                           1.559.427
# 2                      63.276                          83.031.191
# 3                     108.252                         100.235.347
# 4                      35.789                          24.084.423
# 5                      33.859                          21.008.991
# 6                      33.986                          20.882.382
# 7                      34.429                          21.466.600
# 8                      35.852                          22.775.087
# 9                      37.103                          24.309.981
#
#   Irpef a debito - Frequenza Irpef a debito - Ammontare in euro
# 0                        NaN                               None
# 1                        NaN                               None
# 2                    539.000                            325.796
# 3                     30.623                          1.725.834
# 4                     13.102                          1.312.454
# 5                     10.381                          1.494.586
# 6                      9.332                          1.628.892
# 7                      9.493                          1.939.041
# 8                      9.500                          2.125.362
# 9                      9.902                          2.431.176
#
# [10 rows x 31 columns]

# %%
# %%sql
# -- In case of previous errors
# ROLLBACK;
#
# -- Create sequence for auto-increment
# CREATE SEQUENCE classe_id_seq START 1;
# CREATE SEQUENCE sesso_id_seq START 1;
# CREATE SEQUENCE regione_id_seq START 1;
#
# -- In case of previous errors
# DROP TABLE IF EXISTS classe_codes;
# DROP TABLE IF EXISTS sesso_codes;
# DROP TABLE IF EXISTS regione_codes;
#
#
# -- Create lookup tables with auto-increment ID
# CREATE TABLE IF NOT EXISTS classe_codes (
#     id INTEGER PRIMARY KEY DEFAULT nextval('classe_id_seq'),
#     classe_name VARCHAR(255) UNIQUE
# );
#
# CREATE TABLE IF NOT EXISTS sesso_codes (
#     id INTEGER PRIMARY KEY DEFAULT nextval('sesso_id_seq'),
#     sesso_name VARCHAR(255) UNIQUE
# );
#
# CREATE TABLE IF NOT EXISTS regione_codes (
#     id INTEGER PRIMARY KEY DEFAULT nextval('regione_id_seq'),
#     regione_name VARCHAR(255) UNIQUE
# );
#
# -- Extract distinct names from CSV with auto-increment
# INSERT INTO classe_codes (classe_name)
#     SELECT DISTINCT "Classi di reddito complessivo in euro"
#     FROM read_csv('irpef.sesso.2024.csv', header=true)
#     ORDER BY "Classi di reddito complessivo in euro";
#
#
# INSERT INTO sesso_codes (sesso_name)
#     SELECT DISTINCT "Sesso"
#     FROM read_csv('irpef.sesso.2024.csv', header=true)
#     ORDER BY "Sesso";
#
#
# INSERT INTO regione_codes (regione_name)
#     SELECT DISTINCT "Regione"
#     FROM read_csv('irpef.regione.2024.csv', header=true)
#     ORDER BY "Regione";
#
#
#
#
# SELECT * FROM sesso_codes;
# Out:
#    id sesso_name
# 0   1    Femmine
# 1   2     Maschi

# %%
# %%sql
# -- Show the generated IDs
# SELECT * FROM classe_codes;
# Out:
#     id           classe_name
# 0    1         da -1.000 a 0
# 1    2          da 0 a 1.000
# 2    3      da 1.000 a 1.500
# 3    4      da 1.500 a 2.000
# 4    5    da 10.000 a 12.000
# 5    6  da 100.000 a 120.000
# 6    7    da 12.000 a 15.000
# 7    8  da 120.000 a 150.000
# 8    9    da 15.000 a 20.000
# 9   10  da 150.000 a 200.000
# 10  11      da 2.000 a 2.500
# 11  12      da 2.500 a 3.000
# 12  13    da 20.000 a 26.000
# 13  14  da 200.000 a 300.000
# 14  15    da 26.000 a 29.000
# 15  16    da 29.000 a 35.000
# 16  17      da 3.000 a 3.500
# 17  18      da 3.500 a 4.000
# 18  19    da 35.000 a 40.000
# 19  20      da 4.000 a 5.000
# 20  21    da 40.000 a 50.000
# 21  22      da 5.000 a 6.000
# 22  23    da 50.000 a 55.000
# 23  24    da 55.000 a 60.000
# 24  25      da 6.000 a 7.500
# 25  26    da 60.000 a 70.000
# 26  27     da 7.500 a 10.000
# 27  28    da 70.000 a 75.000
# 28  29    da 75.000 a 80.000
# 29  30    da 80.000 a 90.000
# 30  31   da 90.000 a 100.000
# 31  32      minore di -1.000
# 32  33         oltre 300.000
# 33  34                  zero

# %%
# %%sql
# -- Add min_value and max_value columns
# ALTER TABLE classe_codes ADD COLUMN min_value BIGINT;
# ALTER TABLE classe_codes ADD COLUMN max_value BIGINT;
#
# -- Update for standard range format: "da X a Y"
# UPDATE classe_codes
# SET
#     min_value = CAST(REPLACE(REGEXP_EXTRACT(classe_name, 'da (-?[0-9.]+)', 1), '.', '') AS BIGINT),
#     max_value = CAST(REPLACE(REGEXP_EXTRACT(classe_name, 'a (-?[0-9.]+)$', 1), '.', '') AS BIGINT)
# WHERE classe_name LIKE 'da % a %';
#
# -- Update for "minore di -1.000"
# UPDATE classe_codes
# SET
#     min_value = NULL,
#     max_value = CAST(REPLACE(REGEXP_EXTRACT(classe_name, 'minore di (-?[0-9.]+)', 1), '.', '') AS BIGINT)
# WHERE classe_name LIKE 'minore di %';
#
# -- Update for "oltre X" format
# UPDATE classe_codes
# SET
#     min_value = CAST(REPLACE(REGEXP_EXTRACT(classe_name, 'oltre ([0-9.]+)', 1), '.', '') AS BIGINT),
#     max_value = NULL
# WHERE classe_name LIKE 'oltre %';
#
# -- Update for "zero" or exact value
# UPDATE classe_codes
# SET
#     min_value = 0,
#     max_value = 0
# WHERE classe_name = 'zero';
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# -- Show the generated IDs
# SELECT * FROM classe_codes ORDER BY min_value;
# Out:
#     id           classe_name  min_value  max_value
# 0    1         da -1.000 a 0      -1000          0
# 1    2          da 0 a 1.000          0       1000
# 2   34                  zero          0          0
# 3    3      da 1.000 a 1.500       1000       1500
# 4    4      da 1.500 a 2.000       1500       2000
# 5   11      da 2.000 a 2.500       2000       2500
# 6   12      da 2.500 a 3.000       2500       3000
# 7   17      da 3.000 a 3.500       3000       3500
# 8   18      da 3.500 a 4.000       3500       4000
# 9   20      da 4.000 a 5.000       4000       5000
# 10  22      da 5.000 a 6.000       5000       6000
# 11  25      da 6.000 a 7.500       6000       7500
# 12  27     da 7.500 a 10.000       7500      10000
# 13   5    da 10.000 a 12.000      10000      12000
# 14   7    da 12.000 a 15.000      12000      15000
# 15   9    da 15.000 a 20.000      15000      20000
# 16  13    da 20.000 a 26.000      20000      26000
# 17  15    da 26.000 a 29.000      26000      29000
# 18  16    da 29.000 a 35.000      29000      35000
# 19  19    da 35.000 a 40.000      35000      40000
# 20  21    da 40.000 a 50.000      40000      50000
# 21  23    da 50.000 a 55.000      50000      55000
# 22  24    da 55.000 a 60.000      55000      60000
# 23  26    da 60.000 a 70.000      60000      70000
# 24  28    da 70.000 a 75.000      70000      75000
# 25  29    da 75.000 a 80.000      75000      80000
# 26  30    da 80.000 a 90.000      80000      90000
# 27  31   da 90.000 a 100.000      90000     100000
# 28   6  da 100.000 a 120.000     100000     120000
# 29   8  da 120.000 a 150.000     120000     150000
# 30  10  da 150.000 a 200.000     150000     200000
# 31  14  da 200.000 a 300.000     200000     300000
# 32  33         oltre 300.000     300000       <NA>
# 33  32      minore di -1.000       <NA>      -1000

# %%
# %%sql
# ROLLBACK;
# SELECT classe_name, REPLACE(REGEXP_EXTRACT(classe_name, 'da ([0-9.]+)', 1), '.', ''), REPLACE(REGEXP_EXTRACT(classe_name, 'a ([0-9.]+)$', 1), '.', '')
# FROM classe_codes
# WHERE classe_name LIKE 'da % a %';
# Out:
#              classe_name  \
# 0          da -1.000 a 0
# 1           da 0 a 1.000
# 2       da 1.000 a 1.500
# 3       da 1.500 a 2.000
# 4     da 10.000 a 12.000
# 5   da 100.000 a 120.000
# 6     da 12.000 a 15.000
# 7   da 120.000 a 150.000
# 8     da 15.000 a 20.000
# 9   da 150.000 a 200.000
# 10      da 2.000 a 2.500
# 11      da 2.500 a 3.000
# 12    da 20.000 a 26.000
# 13  da 200.000 a 300.000
# 14    da 26.000 a 29.000
# 15    da 29.000 a 35.000
# 16      da 3.000 a 3.500
# 17      da 3.500 a 4.000
# 18    da 35.000 a 40.000
# 19      da 4.000 a 5.000
# 20    da 40.000 a 50.000
# 21      da 5.000 a 6.000
# 22    da 50.000 a 55.000
# 23    da 55.000 a 60.000
# 24      da 6.000 a 7.500
# 25    da 60.000 a 70.000
# 26     da 7.500 a 10.000
# 27    da 70.000 a 75.000
# 28    da 75.000 a 80.000
# 29    da 80.000 a 90.000
# 30   da 90.000 a 100.000
#
#    "replace"(regexp_extract(classe_name, 'da ([0-9.]+)', 1), '.', '')  \
# 0
# 1                                                   0
# 2                                                1000
# 3                                                1500
# 4                                               10000
# 5                                              100000
# 6                                               12000
# 7                                              120000
# 8                                               15000
# 9                                              150000
# 10                                               2000
# 11                                               2500
# 12                                              20000
# 13                                             200000
# 14                                              26000
# 15                                              29000
# 16                                               3000
# 17                                               3500
# 18                                              35000
# 19                                               4000
# 20                                              40000
# 21                                               5000
# 22                                              50000
# 23                                              55000
# 24                                               6000
# 25                                              60000
# 26                                               7500
# 27                                              70000
# 28                                              75000
# 29                                              80000
# 30                                              90000
#
#    "replace"(regexp_extract(classe_name, 'a ([0-9.]+)$', 1), '.', '')
# 0                                                   0
# 1                                                1000
# 2                                                1500
# 3                                                2000
# 4                                               12000
# 5                                              120000
# 6                                               15000
# 7                                              150000
# 8                                               20000
# 9                                              200000
# 10                                               2500
# 11                                               3000
# 12                                              26000
# 13                                             300000
# 14                                              29000
# 15                                              35000
# 16                                               3500
# 17                                               4000
# 18                                              40000
# 19                                               5000
# 20                                              50000
# 21                                               6000
# 22                                              55000
# 23                                              60000
# 24                                               7500
# 25                                              70000
# 26                                              10000
# 27                                              75000
# 28                                              80000
# 29                                              90000
# 30                                             100000

# %%
# %%sql
# -- Show the generated IDs
# SELECT * FROM regione_codes;
# Out:
#     id                      regione_name
# 0    1                           Abruzzo
# 1    2                        Basilicata
# 2    3                          Calabria
# 3    4                          Campania
# 4    5                    Emilia Romagna
# 5    6             Friuli Venezia Giulia
# 6    7                             Lazio
# 7    8                           Liguria
# 8    9                         Lombardia
# 9   10                   Mancante/errata
# 10  11                            Marche
# 11  12                            Molise
# 12  13                          Piemonte
# 13  14                            Puglia
# 14  15                          Sardegna
# 15  16                           Sicilia
# 16  17                           Toscana
# 17  18  Trentino Alto Adige(P.A.Bolzano)
# 18  19   Trentino Alto Adige(P.A.Trento)
# 19  20                            Umbria
# 20  21                     Valle d'Aosta
# 21  22                            Veneto

# %%
# %%sql
# ROLLBACK;
# -- Drop the table to clear the aborted state and old data
# DROP TABLE IF EXISTS irpef_reg;
#
# CREATE TABLE IF NOT EXISTS irpef_reg (
#     classe_id INTEGER,
#     regione_id INTEGER,
#     contribuenti BIGINT,
#     reddito BIGINT,
#     PRIMARY KEY (classe_id,regione_id),
#     FOREIGN KEY (classe_id) REFERENCES classe_codes(id),
#     FOREIGN KEY (regione_id) REFERENCES regione_codes(id)
# );
#
# INSERT INTO irpef_reg (classe_id, regione_id, contribuenti, reddito)
#     SELECT
#     cc.id,
#     rc.id,
#     CAST(REPLACE("Numero contribuenti", '.', '') AS BIGINT),
#     CAST(REPLACE("Reddito complessivo - Ammontare in euro", '.', '') AS BIGINT),
#     FROM read_csv('irpef.regione.2024.csv', header=true) csv
#        INNER JOIN classe_codes cc ON csv."Classi di reddito complessivo in euro" = cc.classe_name
#        INNER JOIN regione_codes rc ON csv."Regione" = rc.regione_name;
#
# SELECT * FROM irpef_reg;
# Out:
#      classe_id  regione_id  contribuenti   reddito
# 0           15          13           152  -2565663
# 1           18          13            53    -22715
# 2           17          13         85410         0
# 3           19          13        141686  60396511
# 4           20          13         34992  43455671
# ..         ...         ...           ...       ...
# 743         23          10            18   1968045
# 744         25          10            10   1398303
# 745         27          10            13   2267911
# 746         31          10            14   3549434
# 747         16          10            34  31502099
#
# [748 rows x 4 columns]

# %%
# %%sql
# ROLLBACK;
# -- Drop the table to clear the aborted state and old data
# DROP TABLE IF EXISTS irpef_sex;
#
# CREATE TABLE IF NOT EXISTS irpef_sex (
#     classe_id INTEGER,
#     sesso_id INTEGER,
#     contribuenti BIGINT,
#     reddito BIGINT,
#     PRIMARY KEY (classe_id,sesso_id),
#     FOREIGN KEY (classe_id) REFERENCES classe_codes(id),
#     FOREIGN KEY (sesso_id) REFERENCES sesso_codes(id)
# );
#
# INSERT INTO irpef_sex (classe_id, sesso_id, contribuenti, reddito)
#     SELECT
#     cc.id,
#     sc.id,
#     CAST(REPLACE("Numero contribuenti", '.', '') AS BIGINT),
#     CAST(REPLACE("Reddito complessivo - Ammontare in euro", '.', '') AS BIGINT),
#     FROM read_csv('irpef.sesso.2024.csv', header=true) csv
#        INNER JOIN classe_codes cc ON csv."Classi di reddito complessivo in euro" = cc.classe_name
#        INNER JOIN sesso_codes sc ON csv."Sesso" = sc.sesso_name;
#
# SELECT * FROM irpef_sex;
# Out:
#     classe_id  sesso_id  contribuenti     reddito
# 0          15         1          1542   -17102700
# 1          18         1           620     -263406
# 2          17         1        670362           0
# 3          19         1        985306   426389300
# 4          20         1        247408   307421998
# ..        ...       ...           ...         ...
# 63         23         2         61362  6680643546
# 64         25         2         42981  5716927324
# 65         27         2         28322  4839525975
# 66         31         2         15578  3695921516
# 67         16         2          8809  4669479836
#
# [68 rows x 4 columns]

# %%
# %%sql
# SELECT regione_name, classe_name, reddito, contribuenti FROM irpef_reg i
# JOIN regione_codes rc ON i.regione_id = rc.id
# JOIN classe_codes cc ON i.classe_id = cc.id
# ORDER BY contribuenti DESC LIMIT 5 ;
# Out:
#      regione_name         classe_name      reddito  contribuenti
# 0       Lombardia  da 20.000 a 26.000  30126521933       1308594
# 1       Lombardia  da 15.000 a 20.000  15283334501        868094
# 2       Lombardia  da 29.000 a 35.000  27541910667        866816
# 3          Veneto  da 20.000 a 26.000  16165822218        701585
# 4  Emilia Romagna  da 20.000 a 26.000  14498038846        629660

# %%
# %%sql
# SELECT 'Somma Regioni:', SUM(contribuenti) FROM irpef_reg
# UNION
# SELECT 'Somma Sesso:', SUM(contribuenti) FROM irpef_sex;
# Out:
#   'Somma Regioni:'  sum(contribuenti)
# 0     Somma Sesso:         42570078.0
# 1   Somma Regioni:         42570059.0

# %%
# %%sql
# SELECT 'Somma Regioni:', SUM(contribuenti) FROM irpef_reg WHERE classe_id = 1
# UNION
# SELECT 'Somma Sesso:', SUM(contribuenti) FROM irpef_sex;

# %% [markdown]
# ----------------
#
# ## Different File: Reviews

# %%
# !wget https://gist.github.com/mosesvemana/f9868d6d2980b39bf8bf5287a28c7d21/raw/d6ba88f7952370582ecc206d47c4fd0d5448ae20/reviews.csv
# Out:
# --2025-11-20 11:41:43--  https://gist.github.com/mosesvemana/f9868d6d2980b39bf8bf5287a28c7d21/raw/d6ba88f7952370582ecc206d47c4fd0d5448ae20/reviews.csv
# Resolving gist.github.com (gist.github.com)... 140.82.112.3
# Connecting to gist.github.com (gist.github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/mosesvemana/f9868d6d2980b39bf8bf5287a28c7d21/raw/d6ba88f7952370582ecc206d47c4fd0d5448ae20/reviews.csv [following]
# --2025-11-20 11:41:43--  https://gist.githubusercontent.com/mosesvemana/f9868d6d2980b39bf8bf5287a28c7d21/raw/d6ba88f7952370582ecc206d47c4fd0d5448ae20/reviews.csv
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1277892 (1.2M) [text/plain]
# Saving to: ‘reviews.csv’
#
# reviews.csv         100%[===================>]   1.22M  --.-KB/s    in 0.05s
#
# 2025-11-20 11:41:44 (24.6 MB/s) - ‘reviews.csv’ saved [1277892/1277892]

# %%
# %%sql
# SELECT * FROM read_csv('reviews.csv') LIMIT 10 ;
# Out:
#    listing_id        id       date  reviewer_id reviewer_name  \
# 0     7202016  38917982 2015-07-19     28943674        Bianca
# 1     7202016  39087409 2015-07-20     32440555         Frank
# 2     7202016  39820030 2015-07-26     37722850           Ian
# 3     7202016  40813543 2015-08-02     33671805        George
# 4     7202016  41986501 2015-08-10     34959538          Ming
# 5     7202016  43979139 2015-08-23      1154501        Barent
# 6     7202016  45265631 2015-09-01     37853266         Kevin
# 7     7202016  46749120 2015-09-13     24445447          Rick
# 8     7202016  47783346 2015-09-21       249583          Todd
# 9     7202016  48388999 2015-09-26     38110731       Tatiana
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...
# 5  Kelly was great, place was great, just what I ...
# 6  Kelly was great! Very nice and the neighborhoo...
# 7  hola all bnb erz - Just left Seattle where I h...
# 8  Kelly's place is conveniently located on a qui...
# 9  The place was really nice, clean, and the most...

# %% [markdown]
# ## Move some data inside a table

# %%
# %%sql
# CREATE TABLE reviewer (
#     rid BIGINT PRIMARY KEY,
#     rname VARCHAR(255)
# );
#
# INSERT INTO reviewer (rid, rname)
#     SELECT DISTINCT reviewer_id as 'rid', reviewer_name as 'rname'
#     FROM read_csv('reviews.csv');
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# SELECT * FROM reviewer ORDER BY rid LIMIT 10;
# Out:
#      rid            rname
# 0   2543  Mike And Fabian
# 1   9763           Taylor
# 2  12793            Kelly
# 3  15174            Scott
# 4  17196           Kawika
# 5  19457              Ron
# 6  26098         Jonathan
# 7  37709              Seh
# 8  38157            Annie
# 9  41555            Craig

# %%
# %%sql
# DROP TABLE IF EXISTS review;
# CREATE TABLE review (
#     review_id BIGINT PRIMARY KEY,
#     apartment_id BIGINT,
#     reviewer_id BIGINT,
#     date DATE,
#     comment TEXT
# );
#
# INSERT INTO review (review_id, apartment_id, reviewer_id, date, comment)
#     SELECT  id, listing_id, reviewer_id, date, comments
#     FROM read_csv('reviews.csv');
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# SELECT COUNT(*) FROM review;
# Out:
#    count_star()
# 0          3044

# %%
# %%sql
# SELECT * FROM review LIMIT 10;
# Out:
#    review_id  apartment_id  reviewer_id       date  \
# 0   38917982       7202016     28943674 2015-07-19
# 1   39087409       7202016     32440555 2015-07-20
# 2   39820030       7202016     37722850 2015-07-26
# 3   40813543       7202016     33671805 2015-08-02
# 4   41986501       7202016     34959538 2015-08-10
# 5   43979139       7202016      1154501 2015-08-23
# 6   45265631       7202016     37853266 2015-09-01
# 7   46749120       7202016     24445447 2015-09-13
# 8   47783346       7202016       249583 2015-09-21
# 9   48388999       7202016     38110731 2015-09-26
#
#                                              comment
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...
# 5  Kelly was great, place was great, just what I ...
# 6  Kelly was great! Very nice and the neighborhoo...
# 7  hola all bnb erz - Just left Seattle where I h...
# 8  Kelly's place is conveniently located on a qui...
# 9  The place was really nice, clean, and the most...

# %%
# %%sql
# SELECT date, comment
# FROM review
# WHERE comment LIKE '%pool%';
# Out:
#         date                                            comment
# 0 2015-05-26  Kirsten's home is lovely. We had access to a n...
# 1 2014-05-28  The apartment was very nice and luxurious. It ...
# 2 2015-05-21  Jordan & Stay Alfred provided thorough, detail...
# 3 2015-11-27  We had a great trip and loved this condo and l...
# 4 2014-11-24  The room was as described and the view was won...

# %%
# %%sql
# SELECT COUNT(*)
# FROM review
# WHERE date BETWEEN  '2015-07-01' AND  '2015-07-31';
# Out:
#    count_star()
# 0           231

# %% [markdown]
# In SQL we can use some special functions to process the values in the columns,
# for example see `strftime` which works with date/time and how to extract values
#
# https://duckdb.org/docs/sql/functions/dateformat.html

# %%
# %%sql
# SELECT strftime('%Y', date) AS review_year, COUNT(*) AS review_count
# FROM review
# GROUP BY review_year
# ORDER BY review_year DESC;
# Out:
#   review_year  review_count
# 0        2016             6
# 1        2015          1932
# 2        2014           650
# 3        2013           234
# 4        2012           183
# 5        2011            39

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Q1: Find the number of different apartments with a review

# %% [markdown]
# ### Q2: Find the date of the first review written

# %% [markdown]
# ### Q3: Find the number of apartments with more than 1 review

# %% [markdown]
# ### Q4: Find the names of all reviewers with more than 3 review
#
# __Can you use a nested query?__

# %% [markdown]
# ### Q5: Find the user that has written the largest number of reviews

# %% [markdown]
# ### Q6: Find the top-5 apartments with the largest number of reviews

# %% [markdown]
# ## We can export to file and also load from file
# **Note:** DuckDB export 3 files:
#
# 1. A file to create the scehma
# 2. One or more files containing the data
# 3. A file to load the data

# %%
# %%sql
# EXPORT DATABASE 'reviews_db';
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# DROP TABLE IF EXISTS reviewer;
# DROP TABLE IF EXISTS review;
# IMPORT DATABASE 'reviews_db';
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []
