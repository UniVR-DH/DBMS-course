# %% [markdown]
# <a href="https://colab.research.google.com/github/UniVR-DH/DBMS-course/blob/main/notebooks/duckdb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DuckDB in Jupyter Notebooks
# A streamlined workflow for SQL analysis with DuckDB and Jupyter

# %% [markdown]
# ## Library Import and Configuration

# %%
# !pip install --quiet duckdb
# !pip install --quiet jupysql
# !pip install --quiet duckdb-engine
# !pip install --quiet pandas
# !pip install --quiet matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.9/95.9 kB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.8/192.8 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 kB 768.7 kB/s eta 0:00:00

# %%
import duckdb
import pandas as pd
# Import jupysql Jupyter extension to create SQL cells
# %load_ext sql
# Out:
# Deploy Streamlit apps for free on Ploomber Cloud! Learn more: https://ploomber.io/s/signup

# %% [markdown]
# :We configure jupysql to return data as a Pandas dataframe and have less verbose output

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
# %sql duckdb:///:memory:

# %% [markdown]
# An entire Jupyter cell can be used as a SQL cell by placing `%%sql` at the start of the cell. Query results will be displayed as a Pandas DF.

# %%
# %%sql
# SELECT COUNT(*) FROM read_csv('eventi.csv') ;
# Out:
#    count_star()
# 0           100

# %%
# %%sql
# SELECT * FROM read_csv('eventi.csv') ORDER BY column09 ;
# Out:
#                                              column00  \
# 0   http://dati.beniculturali.it/mibact/eventi/res...
# 1   http://dati.beniculturali.it/mibact/eventi/res...
# 2   http://dati.beniculturali.it/mibact/eventi/res...
# 3   http://dati.beniculturali.it/mibact/eventi/res...
# 4   http://dati.beniculturali.it/mibact/eventi/res...
# ..                                                ...
# 95  http://dati.beniculturali.it/mibact/eventi/res...
# 96  http://dati.beniculturali.it/mibact/eventi/res...
# 97  http://dati.beniculturali.it/mibact/eventi/res...
# 98  http://dati.beniculturali.it/mibact/eventi/res...
# 99  http://dati.beniculturali.it/mibact/eventi/res...
#
#                                              column01   column02   column03  \
# 0                                      BORT. AL museo 2019-09-21 2019-09-21
# 1       Museo Omero - Giornate Europee del Patrimonio 2019-09-21 2019-09-21
# 2            Pinacoteca Civica di Ancona - Conferenze 2019-09-12 2019-09-13
# 3                                     Shakti Festival 2019-09-14 2019-09-15
# 4   Palazzo Taglieschi-Per non dimenticare.Dedicat... 2019-09-20 2019-09-20
# ..                                                ...        ...        ...
# 95  "I colori delle statue. Scultura antica, ricer... 2019-09-21 2019-09-21
# 96  Le imbarcazioni storiche del Comune di Venezia... 2019-09-21 2019-09-21
# 97   Vasi apuli al Museo di Vigevano - visite guidate 2019-09-21 2019-09-21
# 98  Museo Archeologico Nazionale della Lomellina -... 2019-09-21 2019-09-21
# 99             Simboli ed emblemi del potere in Villa 2019-09-21 2019-09-21
#
#                   column04  column05                column06  \
# 0   Apertura Straordinaria         3               Via Parma
# 1       Attività Didattica  Gratuito      Mole Vanvitelliana
# 2      Convegno/conferenza  Gratuito  Via Ciriaco Pizzecolli
# 3                 Festival         4  Via Ciriaco Pizzecolli
# 4                 Concerto         2           piazza Mameli
# ..                     ...       ...                     ...
# 95          Visita Guidata  Gratuito      Piazzetta S. Marco
# 96          Visita Guidata  Gratuito                Castello
# 97          Visita Guidata  Gratuito           piazza Ducale
# 98  Apertura Straordinaria  Gratuito           piazza Ducale
# 99          Visita Guidata         1      via Jacopo Barozzi
#
#                         column07 column08     column09     column10  \
# 0                              1    15121  Alessandria  Alessandria
# 1   Banchina Giovanni da Chio 28    60121       Ancona       Ancona
# 2                             17    60121       Ancona       Ancona
# 3                             17    60121       Ancona       Ancona
# 4                         s.n.c.    52031     Anghiari       Arezzo
# ..                           ...      ...          ...          ...
# 95                         n. 17    30124      Venezia      Venezia
# 96           Campo dell’Arsenale    67100      Venezia      Venezia
# 97                            20    27029     Vigevano        Pavia
# 98                            20    27029     Vigevano        Pavia
# 99                            71    01100      Viterbo      Viterbo
#
#      column11                                           column12
# 0    Piemonte  Nuova mostra del noto disegnatore e vignettist...
# 1      Marche  In occasione delle Giornate Europee del Patrim...
# 2      Marche  Giovedi 12 settembre, ore 16.45, conferenza da...
# 3      Marche  Sabato 14 e domenica 15 settembre la Pinacotec...
# 4     Toscana  Arezzo - Musei statali e Archivio di Stato."Pe...
# ..        ...                                                ...
# 95     Veneto  a cura di Marcella De Paolialle ore 16 e 17.30...
# 96     Veneto  L’iniziativa, in collaborazione con il Comune ...
# 97  Lombardia  Sabato 21 settembre il Museo Archeologico Nazi...
# 98  Lombardia  In occasione dell'appuntamento con le Giornate...
# 99      Lazio  In occasione delle Giornate Europee del Patrim...
#
# [100 rows x 13 columns]

# %%
# %%sql
# CREATE TABLE eventi AS
#     SELECT column00 as 'url', column01 as 'titolo', column02 as 'inizio', column03 as 'fine',
#     column04 as 'categoria',  column05 as 'prezzo', column06 as 'indirizzo', column07 as  'civico',
#     column08 as 'CAP', column09 as 'comune', column10 as 'provincia', column11 as 'regione', column12 as 'descrizione'
#     FROM read_csv('eventi.csv');
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# SELECT * FROM eventi;
# Out:
#                                                   url  \
# 0   http://dati.beniculturali.it/mibact/eventi/res...
# 1   http://dati.beniculturali.it/mibact/eventi/res...
# 2   http://dati.beniculturali.it/mibact/eventi/res...
# 3   http://dati.beniculturali.it/mibact/eventi/res...
# 4   http://dati.beniculturali.it/mibact/eventi/res...
# ..                                                ...
# 95  http://dati.beniculturali.it/mibact/eventi/res...
# 96  http://dati.beniculturali.it/mibact/eventi/res...
# 97  http://dati.beniculturali.it/mibact/eventi/res...
# 98  http://dati.beniculturali.it/mibact/eventi/res...
# 99  http://dati.beniculturali.it/mibact/eventi/res...
#
#                                                titolo     inizio       fine  \
# 0                                   Convegno di Studi 2010-10-07 2010-10-09
# 1   Viaggio in Italia dell'emiro Fakhr ad - Din al... 2014-02-27 2014-02-27
# 2   Cultura è partecipazione: Visite guidate al museo 2017-09-23 2017-09-24
# 3   SALONE INTERNAZIONALE DEL RESTAURO, DEI MUSEI ... 2018-03-21 2018-03-23
# 4    Salone dell'Arte e del Restauro di Firenze_Copia 2018-05-15 2018-05-18
# ..                                                ...        ...        ...
# 95  Museo Archeologico Nazionale della Lomellina -... 2019-09-21 2019-09-21
# 96  Giornate Europee del Patrimonio 2019 - Archivi... 2019-09-21 2019-09-21
# 97  Giornate Europee del Patrimonio 2019 - Archivi... 2019-09-21 2019-09-21
# 98          Noci, astragali e giochi dell'antica Roma 2019-09-21 2019-09-21
# 99  L'otto per mille per la conservazione del patr... 2019-09-21 2019-09-21
#
#                     categoria    prezzo                     indirizzo civico  \
# 0                       Altro         0  Piazza San Giovanni Paolo II     5A
# 1      Incontro/presentazione  Gratuito                    via Cavour      1
# 2              Visita Guidata         5                 Via Seminario     26
# 3   Manifestazione Fieristica         0               Via della Fiera     11
# 4   Manifestazione Fieristica         0                   piazza Adua      1
# ..                        ...       ...                           ...    ...
# 95     Apertura Straordinaria  Gratuito                 piazza Ducale     20
# 96     Apertura Straordinaria  Gratuito           Corso F.lli Cairoli    175
# 97     Apertura Straordinaria  Gratuito        Corso Fratelli Cairoli    175
# 98         Attività Didattica  Gratuito        Piazza Vittorio Veneto     14
# 99        Convegno/conferenza  Gratuito         Piazza Giordano Bruno     10
#
#       CAP       comune provincia         regione  \
# 0   43121        Parma     Parma  Emilia-Romagna
# 1   50121      Firenze   Firenze         Toscana
# 2   30026  Portogruaro   Venezia          Veneto
# 3   44124      Ferrara   Ferrara  Emilia-Romagna
# 4   50100      Firenze   Firenze         Toscana
# ..    ...          ...       ...             ...
# 95  27029     Vigevano     Pavia       Lombardia
# 96  62100     Macerata  Macerata          Marche
# 97  62100     Macerata  Macerata          Marche
# 98  46020    Pegognaga   Mantova       Lombardia
# 99  06121      Perugia   Perugia          Umbria
#
#                                           descrizione
# 0   \n\nStruttura, architettura e decorazione dell...
# 1   \n\nGiovedì  27 febbraio alle ore 17.00 nel Sa...
# 2   I giorni 23 e 24 settembre 2017 dalle ore 15.0...
# 3   Dal 21 al 23 marzo 2018 a Ferrara, il Minister...
# 4   Da mercoledì 16 a venerdì 18 maggio 2018, pres...
# ..                                                ...
# 95  In occasione dell'appuntamento con le Giornate...
# 96  L’Archivio di Stato di Macerata, in data 21 se...
# 97  L’Archivio di Stato di Macerata, in data 21 se...
# 98  Nel tempo libero gli antichi Romani, grandi e ...
# 99  Nel corso della conferenza verranno illustrati...
#
# [100 rows x 13 columns]

# %%
# %%sql
# SELECT COUNT(*) FROM eventi;
# Out:
#    count_star()
# 0           100

# %%
# %%sql
# EXPORT DATABASE 'eventi';
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# DROP TABLE eventi;
# IMPORT DATABASE 'eventi';
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# SELECT COUNT(*) FROM eventi;
# Out:
#    count_star()
# 0           100
